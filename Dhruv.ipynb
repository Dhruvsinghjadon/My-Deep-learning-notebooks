# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruvsinghjadon/My-Deep-learning-notebooks/blob/main/Dhruv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
dataset= pd.read_csv('/content/Jaimala-Midsem Ist  software engineering CSE-grades.csv')
x= dataset.iloc[:,:].values
print(x)
y= dataset.iloc[:,3:].values
print (y)
# Out:
# [['AARAV GOYAL' '0901CS201001' 'aaravgoyal86@gmail.com' 19]
#  ['ABHAY PRATAP SINGH' '0901CS201002' 'abhaypratap.de@gmail.com' 18]
#  ['ADITYA FAIYA' '0901CS201003' 'adityafaiya@gmail.com' 19]
#  ['ADITYA GUPTA' '0901CS201004' 'aditya8529468873@gmail.com' 19]
#  ['ADITYA PRAJAPATI' '0901CS201005' 'adityaprajapati010103@gmail.com' 19]
#  ['ADITYA RAJ SHRIVASTAVA' '0901CS201006'
#   'adityarajshrivastava8755@gmail.com' 19]
#  ['ADITYA RAJ SHUKLA' '0901CS201007' 'adityarajskh002@gmail.com' 18]
#  ['AJAY GURJAR' '0901CS201008' 'ajaygurjar048@gmail.com' 18]
#  ['AJAY SINGH MARKAM' '0901CS201009' 'ajaysinghmarkam70@gmail.com' 16]
#  ['Ajinendra Rajpoot' '0901CS201010' 'ajinendra2002@gmail.com' 19]
#  ['AKANSHA SAKHRE' '0901CS201011' 'akanshasakhre@gmail.com' 16]
#  ['AKASH SINGH' '0901CS201012' 'akashsinghsaini2616@gmail.com' 19]
#  ['AKRITEE JAIN' '0901CS201013' 'akriteejain.30.01@gmail.com' 18]
#  ['ALKA YADAV' '0901CS201015' 'alkayadav0014@gmail.com' 19]
# ...

# %%
from sklearn.impute import SimpleImputer
imputer= SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(x[:,3:])
x[:,3:] = imputer.transform (x[:,3:])
x
# Out:
# array([['AARAV GOYAL', '0901CS201001', 'aaravgoyal86@gmail.com', 19.0],
#        ['ABHAY PRATAP SINGH', '0901CS201002', 'abhaypratap.de@gmail.com',
#         18.0],
#        ['ADITYA FAIYA', '0901CS201003', 'adityafaiya@gmail.com', 19.0],
#        ['ADITYA GUPTA', '0901CS201004', 'aditya8529468873@gmail.com',
#         19.0],
#        ['ADITYA PRAJAPATI', '0901CS201005',
#         'adityaprajapati010103@gmail.com', 19.0],
#        ['ADITYA RAJ SHRIVASTAVA', '0901CS201006',
#         'adityarajshrivastava8755@gmail.com', 19.0],
#        ['ADITYA RAJ SHUKLA', '0901CS201007', 'adityarajskh002@gmail.com',
#         18.0],
#        ['AJAY GURJAR', '0901CS201008', 'ajaygurjar048@gmail.com', 18.0],
#        ['AJAY SINGH MARKAM', '0901CS201009',
#         'ajaysinghmarkam70@gmail.com', 16.0],
#        ['Ajinendra Rajpoot', '0901CS201010', 'ajinendra2002@gmail.com',
#         19.0],
#        ['AKANSHA SAKHRE', '0901CS201011', 'akanshasakhre@gmail.com',
#         16.0],
# ...
